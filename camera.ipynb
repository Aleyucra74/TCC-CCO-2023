# %%
import os
import cv2
import boto3
from botocore.exceptions import NoCredentialsError
from datetime import datetime

# %%
aws_access_key_id='ASIA535JPIX37G66DDLB'
aws_secret_access_key='44vfT3NTFFEyqjxlfORytFgPQwazR1Q8+PZt5vp5'
aws_session_token=''

# %%
s3 = boto3.client(
    service_name='s3',
    region_name='us-east-1',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    aws_session_token=aws_session_token
)

# %%
today = datetime.now().strftime('%d%m%Y')

nomeArquivo = f'{today}.mp4'

vid = cv2.VideoCapture(0)

largura= int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
altura= int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))

writer= cv2.VideoWriter(nomeArquivo, cv2.VideoWriter_fourcc(*'DIVX'), 20, (largura,altura))

while(True):

    ret, frame = vid.read()
    writer.write(frame)
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
  

vid.release()
writer.release()
cv2.destroyAllWindows()

# %%
def dividir_frames(entrada, saida):

    video = cv2.VideoCapture(entrada)

    if not video.isOpened():
        print("Error opening video file")
        return

    os.makedirs(saida, exist_ok=True)

    contadorFrame = 0

    while True:
        ret, frame = video.read()
        if not ret:
            break

        pastaFrame = os.path.join(saida, f"frame{contadorFrame}.jpg")
        cv2.imwrite(pastaFrame, frame)
        print(f"Frame {contadorFrame} salvo em '{pastaFrame}'")

        contadorFrame += 1

    # Release the video capture object
    video.release()

# Usage example
videoUsado = nomeArquivo 
saida = f'path/to/{today}'

dividir_frames(videoUsado, saida)
# Out:
# Frame 0 salvo em 'path/to/25062023\frame0.jpg'
# Frame 1 salvo em 'path/to/25062023\frame1.jpg'
# Frame 2 salvo em 'path/to/25062023\frame2.jpg'
# Frame 3 salvo em 'path/to/25062023\frame3.jpg'
# Frame 4 salvo em 'path/to/25062023\frame4.jpg'
# Frame 5 salvo em 'path/to/25062023\frame5.jpg'
# Frame 6 salvo em 'path/to/25062023\frame6.jpg'
# Frame 7 salvo em 'path/to/25062023\frame7.jpg'
# Frame 8 salvo em 'path/to/25062023\frame8.jpg'
# Frame 9 salvo em 'path/to/25062023\frame9.jpg'
# Frame 10 salvo em 'path/to/25062023\frame10.jpg'
# Frame 11 salvo em 'path/to/25062023\frame11.jpg'
# Frame 12 salvo em 'path/to/25062023\frame12.jpg'
# Frame 13 salvo em 'path/to/25062023\frame13.jpg'
# Frame 14 salvo em 'path/to/25062023\frame14.jpg'
# Frame 15 salvo em 'path/to/25062023\frame15.jpg'
# Frame 16 salvo em 'path/to/25062023\frame16.jpg'
# Frame 17 salvo em 'path/to/25062023\frame17.jpg'
# Frame 18 salvo em 'path/to/25062023\frame18.jpg'
# Frame 19 salvo em 'path/to/25062023\frame19.jpg'
# ...

# %%
def upload_files_to_s3(file_paths, bucket_name):
    for file_path in file_paths:
        try:
            file_name = os.path.basename(file_path)
            s3.upload_file(file_path, bucket_name, f'{today}/'+file_name)
            print(f"File uploaded: {file_name}")
        except NoCredentialsError:
            print("No AWS credentials found.")
            return
        except Exception as e:
            print(f"Error uploading file: {file_name} - {e}")

# Usage example
# directory_path = saida  # Path to the directory containing the files
bucket_name = 'teste-novamente-crime'  # Name of your S3 bucket

file_paths = []
for file_name in os.listdir(saida):
    file_path = os.path.join(saida, file_name)
    if os.path.isfile(file_path):
        file_paths.append(file_path)

upload_files_to_s3(file_paths, bucket_name)
# Out:
# Error uploading file: frame0.jpg - Failed to upload path/to/25062023\frame0.jpg to teste-novamente-crime/25062023/frame0.jpg: An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
# Error uploading file: frame1.jpg - Failed to upload path/to/25062023\frame1.jpg to teste-novamente-crime/25062023/frame1.jpg: An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
# Error uploading file: frame10.jpg - Failed to upload path/to/25062023\frame10.jpg to teste-novamente-crime/25062023/frame10.jpg: An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
# Error uploading file: frame100.jpg - Failed to upload path/to/25062023\frame100.jpg to teste-novamente-crime/25062023/frame100.jpg: An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
# ...
